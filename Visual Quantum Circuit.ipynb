# %%
# !pip install qiskit
# Out:
# Requirement already satisfied: qiskit in c:\users\admin\conda distribution\lib\site-packages (0.45.1)
# Requirement already satisfied: qiskit-terra==0.45.1 in c:\users\admin\conda distribution\lib\site-packages (from qiskit) (0.45.1)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (1.24.3)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (5.9.0)
# Requirement already satisfied: scipy>=1.5 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (1.10.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (1.11.1)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (0.3.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\admin\conda distribution\lib\site-packages (from qiskit-terra==0.45.1->qiskit) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\conda distribution\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.1->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\admin\conda distribution\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.1->qiskit) (6.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\conda distribution\lib\site-packages (from sympy>=1.3->qiskit-terra==0.45.1->qiskit) (1.3.0)

# %%
import networkx as nx
import numpy as np
import matplotlib as mpl
import plotly.graph_objects as go
from qiskit import Aer
from matplotlib import pyplot as plt
from qiskit import QuantumCircuit
from qiskit.visualization import plot_state_city
from qiskit.algorithms.optimizers import COBYLA, SLSQP, ADAM
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4588\4191334811.py:9: DeprecationWarning: ``qiskit.algorithms`` has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. The ``qiskit.algorithms`` import path is deprecated as of qiskit-terra 0.25.0 and will be removed no earlier than 3 months after the release date. Please run ``pip install qiskit_algorithms`` and use ``import qiskit_algorithms`` instead.
#   from qiskit.algorithms.optimizers import COBYLA, SLSQP, ADAM

# %%
pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in c:\users\admin\conda distribution\lib\site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import QuantumCircuit, ClassicalRegister
from qiskit.circuit import Parameter

# Creating a Quantum Circuit with 8 qubits
circuit = QuantumCircuit(8)
cr = ClassicalRegister(8)
circuit.add_register(cr)

# Define a 2D parameter array for rotation angles
theta = [[Parameter(f'θ[{control},{target}]') for target in range(8)] for control in range(8)]

# Apply RY gates to each qubit with the parameter theta[control, control]
for qubit in range(8):
    circuit.ry(theta[qubit][qubit], qubit)

circuit.barrier()

# Applying controlled-RY gates with parameters theta[control, target] for the first qubit
control_qubit = 0
for target_qubit in range(1, 8):
    circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)

circuit.barrier()

control_qubit = 1
for target_qubit in range(8):
    if target_qubit != 1:  
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
control_qubit = 2
for target_qubit in range(8):
    if target_qubit != 2:  
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
control_qubit = 3
for target_qubit in range(8):
    if target_qubit != 3:  
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
control_qubit = 4
for target_qubit in range(8):
    if target_qubit != 4: 
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
control_qubit = 5
for target_qubit in range(8):
    if target_qubit != 5: 
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
control_qubit = 6
for target_qubit in range(8):
    if target_qubit != 6:  
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
control_qubit = 7
for target_qubit in range(8):
    if target_qubit != 7:  
        circuit.cry(theta[control_qubit][target_qubit], control_qubit, target_qubit)
circuit.barrier()
circuit.measure(range(8), range(8))

circuit.draw('mpl')
